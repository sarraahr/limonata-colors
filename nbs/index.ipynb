# %% [markdown]
# # limonata
#
# > An immaculate resource for giving your plots the perfect touch of color they deserve.

# %% [markdown]
# ## Install
#
# Either using `pip`:
#
# ```sh
# pip install limonata
# ```
#
# or `conda`:
#
# ```sh
# conda install limonata
# ```

# %% [markdown]
# ## How to use
#
# You can currently set a "nature" or a "city" palette.
# These are palettes we created from pictures we took.
# Use the following functions to set a palette:

# %%
from limonata import set_city_palette
set_city_palette("TuebingenClassic")

# %% [markdown]
# Or you can see which palettes are available with the following functions:

# %%
from limonata import show_nature_palettes
show_nature_palettes()

# %% [markdown]
# See the documentation [here](https://sarraahr.github.io/limonata) for more details and examples.
